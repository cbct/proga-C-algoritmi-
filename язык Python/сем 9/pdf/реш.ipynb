# %% [markdown]
# Семинар 9
#
# На этом семинаре мы будем работать с известной базой данных
# (http://campus.lakeforest.edu/frank/FILES/MLFfiles/Bio150/Titanic/TitanicMETA.pdf) по пассажирам
#
# "Титаника" (она часто используется в курсах по эконометрике и машинному обучению, но представляетне только статистической, но и содержательный интерес).
#
# Переменные:
#
# PassengerId - id пассажира
#
# Survived - бинарный показатель, выжил пассажир или нет (1 - выжил, 0 - не выжил)
#
# Pclass - класс пассажира
#
# Name - имя пассажира
#
# Sex - пол пассажира
#
# Age - возраст пассажира
#
# SibSp - число родных братьев/сестер пассажира на борту корабля (или супругов)
#
# Parch - число родителей пассажира на борту корабля
#
# Ticket - номер билета
#
# Fare - стоимость билета
#
# Cabin - каюта
#
# Embarked - порт, в котором пассажир взошел на палубу корабля

# %% [markdown]
# Загрузка и предварительная обработка
#
# 1.    Загрузите базу данных из файла Titanic.csv .
# 2.    Загрузите базу данных так из файла еще раз, но так, чтобы столбец PassengerId был идентификатором, то есть номером строки (index).
# 3.   Удалите из базы строки с пропущенными значениями и сохраните изменения в самой базе.

# %% [markdown]
# Описание базы данных
#
#
#
# 4.   Выведите сводную информацию по базе данных: какие переменные в ней есть, какого они типа + сколько заполненных наблюдений в каждой столбце.
# 5.    Выведите сводную статистическую информацию по каждому количественному показателю в базе (описательные статистике).
# 6.   Постройте гистограмму для переменной Возраст (Age), сделайте ее красного цвета, подпишите оси и добавьте заголовок графика.
# 7.   Выведите описательные статистики для столбца Стоимость билета (Fare).

# %% [markdown]
# Работа со строками и столбцами базы
#
#
# 8.   Выведите названия столбцов в базе данных в виде списка (объект типа list).
# 9.    Переименуйте столбец с классом пассажира из Pclass в Class.
# 10.   Выберите из базы данных все строки, которые соответствуют пассажирам женского пола, и сохраните их в новую базу female .
# 11.    Выберите из базы данных все строки, которые соответствуют выжившим пассажирам мужского пола младше 32 лет, и сохраните их в базу Ymale.
# 12.    Выберите из базы данных все строки, которые соответствуют пассажирам 1 или 2 класса.
# 13.    Выберите из базы данных все строки, которые соответствуют выжившим пассажирам 1 или 2 класса.
# 14.   Добавьте в датафрейм столбец Female, состоящий из значений 0 и 1, где 1 соответствует
# пассажирам женского пола.

# %% [markdown]
# Группировка
#
#
#
# 1.   Выведите на экран все уникальные значения в столбце Embarked
# 2.    Сгруппируйте строки в датафрейме в соответствии со значениями переменной Survived и выведите средние значения всех количественных переменных по группам.
# 3.   Сгруппируйте строки в датафрейме в соответствии со значениями переменной Sex и сохраните в отдельный датафрейм таблицу со средними и медианными значениями переменной Age по группам(мужчины и женщины).

# %% [markdown]
# Выгрузка базы в файл
#
# 1.   Приведите все названия столбцов в датафрейме к нижнему регистру и сохраните изменения.
# 2.    Выгрузите итоговый датафрейм в файл Titanic-new.csv .

# %%
import pandas as pd
# 1 Загрузите базу данных из файла Titanic.csv .
df = pd.read_csv("C:\Windows\System32\AppLocker\Titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 2 Загрузите базу данных так из файла еще раз, но так, 
# чтобы столбец PassengerId был идентификатором, то есть номером строки (index).
df['PassengerId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
# 3 Удалите из базы строки с пропущенными значениями и сохраните изменения в самой базе.
df = df.dropna()  # удаляем и сохраняем изменения
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 4 Выведите сводную информацию по базе данных: какие переменные в ней есть, 
# какого они типа + сколько заполненных наблюдений в каждой столбце.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
# 5 Выведите сводную статистическую информацию по каждому количественному 
# показателю в базе (описательные статистике).
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
# 6 Постройте гистограмму для переменной Возраст (Age), сделайте ее 
# красного цвета ,подпишите оси и добавьте заголовок графика.
import matplotlib.pyplot as plt
# %matplotlib inline
df["Age"].plot.hist(color = "red") # histogram
plt.title("Возраст", size = 20)
plt.xlabel("Лет", size = 14)
plt.ylabel("Количество людей", size = 14)
# Out:
# Text(0, 0.5, 'Количество людей')

# %%
# 7 Выведите описательные статистики для столбца Стоимость билета (Fare).
df["Fare"].describe()
# Out:
# count    183.000000
# mean      78.682469
# std       76.347843
# min        0.000000
# 25%       29.700000
# 50%       57.000000
# 75%       90.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# 8 Выведите названия столбцов в базе данных в виде списка (объект типа list).
list_columns = list(df.columns)
print(list_columns)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# 9 Переименуйте столбец с классом пассажира из Pclass в Class.
my_cols = list(df.columns)
my_cols[2] = "Class"
df.columns = my_cols # сохраним изменения в самой базе df
df.columns # все обновилось!
# Out:
# Index(['PassengerId', 'Survived', 'Class', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 10 Выберите из базы данных все строки, которые соответствуют 
# пассажирам женского пола, и сохраните их в новую базу female .
female = df[df["Sex"] == "female"] 
female
# Out:
#      PassengerId  Survived  Class  \
# 1              2         1      1
# 3              4         1      1
# 10            11         1      3
# 11            12         1      1
# 52            53         1      1
# ..           ...       ...    ...
# 853          854         1      1
# 862          863         1      1
# 871          872         1      1
# 879          880         1      1
# 887          888         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
female.to_csv(r"C:\Windows\System32\AppLocker\female.csv", index = True, sep=";")

# %%
# 11 Выберите из базы данных все строки, которые соответствуют выжившим пассажирам 
#  мужского пола младше 32 лет, и сохраните их в базу Ymale.
Ymale = df[(df["Sex"] == "male") & (df["Age"] < 32)] 
Ymale
# Out:
#      PassengerId  Survived  Class                                        Name  \
# 23            24         1      1                Sloper, Mr. William Thompson
# 27            28         0      1              Fortune, Mr. Charles Alexander
# 75            76         0      3                     Moen, Mr. Sigurd Hansen
# 97            98         1      1             Greenfield, Mr. William Bertram
# 102          103         0      1                   White, Mr. Richard Frasar
# 118          119         0      1                    Baxter, Mr. Quigg Edmond
# 139          140         0      1                          Giglio, Mr. Victor
# 183          184         1      2                   Becker, Master. Richard F
# 193          194         1      2                  Navratil, Master. Michel M
# 305          306         1      1              Allison, Master. Hudson Trevor
# 336          337         0      1                   Pears, Mr. Thomas Clinton
# ...

# %%
# 11 Выберите из базы данных все строки, которые соответствуют выжившим пассажирам
#  мужского пола младше 32 лет, и сохраните их в базу Ymale.
Ymale = df[(df["Sex"] == "male") & (df["Age"] < 32)]
Ymale

# %%
# 12 Выберите из базы данных все строки, 
# которые соответствуют пассажирам 1 или 2 класса.
df[(df["Class"] == 1) | (df["Class"] == 2) ]
# Out:
#      PassengerId  Survived  Class  \
# 1              2         1      1
# 3              4         1      1
# 6              7         0      1
# 11            12         1      1
# 21            22         1      2
# ..           ...       ...    ...
# 871          872         1      1
# 872          873         0      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 13 Выберите из базы данных все строки,
# которые соответствуют выжившим пассажирам 1 или 2 класса.
df[((df["Class"] == 1) | (df["Class"] == 2))  & (df["Survived"] == 1)]
# Out:
#      PassengerId  Survived  Class  \
# 1              2         1      1
# 3              4         1      1
# 11            12         1      1
# 21            22         1      2
# 23            24         1      1
# ..           ...       ...    ...
# 862          863         1      1
# 871          872         1      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 14 Добавьте в датафрейм столбец Female, состоящий из значений 0 и 1, 
# где 1 соответствует пассажирам женского пола.
my_list = list(df["Sex"] == "female" if 1 else 0)
df['Female'] = my_list
df['Female'] = df['Female'].replace(to_replace = [True , False], value=[1, 0])
df
# Out:
#      PassengerId  Survived  Class  \
# 1              2         1      1
# 3              4         1      1
# 6              7         0      1
# 10            11         1      3
# 11            12         1      1
# ..           ...       ...    ...
# 871          872         1      1
# 872          873         0      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Группировка
#1 Выведите на экран все уникальные значения в столбце Embarked
df["Embarked"].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
# 2 Сгруппируйте строки в датафрейме в соответствии 
# со значениями переменной Survived и выведите средние значения
# всех количественных переменных по группам.
df.groupby(["Survived"]).mean(numeric_only=True)
# Out:
#           PassengerId     Class        Age     SibSp     Parch       Fare  \
# Survived
# 0          402.983333  1.216667  41.350000  0.366667  0.450000  64.048262
# 1          480.918699  1.178862  32.905854  0.512195  0.487805  85.821107
#
#             Female
# Survived
# 0         0.100000
# 1         0.666667

# %%
# 3 Сгруппируйте строки в датафрейме в соответствии со значениями переменной Sex 
# и вывести среднее и медианное значениями 
# переменной Age по группам(мужчины и женщины).
Mean_df = df.groupby(["Sex"]).Age.mean()
Mean_df
# Out:
# Sex
# female    32.676136
# male      38.451789
# Name: Age, dtype: float64

# %%
df.groupby(["Sex"]).Age.median()
# Out:
# Sex
# female    32.25
# male      37.00
# Name: Age, dtype: float64

# %%
# 1 Приведите все названия столбцов в датафрейме 
# к нижнему регистру и сохраните изменения.
my_cols = list(df.columns)
for i in range(0,len(my_cols)):
   my_cols[i] = my_cols[i].lower()
df.columns = my_cols # сохраним изменения в самой базе df
df.columns # все обновилось!
# Out:
# Index(['passengerid', 'survived', 'class', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'female'],
#       dtype='object')

# %%
# 2 Выгрузите итоговый датафрейм в файл Titanic-new.csv .
df.to_csv(r"C:\Windows\System32\AppLocker\Titanic-new.csv", index = True, sep=";")
